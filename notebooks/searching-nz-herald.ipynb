# %% [markdown]
# # Searching for Māori language text in the NZ Herald archives

# %% [markdown]
# I have collected about 450,000 NZ Herald articles. We want to search them for māori words to see how the use of Te Reo Māori in the NZ Herald has changed over time.

# %%
import re
import jsonlines
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_rows', 500)

from utils import parallel_process
from multiprocessing import cpu_count
from nltk.tokenize import word_tokenize

from reo_toolkit import is_maori, vowels, consonants, ambiguous

# %%
nzherald = []
with jsonlines.open('../data/nzherald.json') as reader:
    for obj in reader:
        nzherald.append(obj)

# %%
nzherald[0]
# Out:
# {'url': 'https://www.nzherald.co.nz/nz/news/article.cfm?c_id=1&objectid=12329090',
#  'byline': None,
#  'date': '2 May, 2020 12:44pm',
#  'headline': [' Six more Covid-19 cases; Chch man dies of coronavirus  '],
#  'sponsor': [],
#  'subheader': ['The latest Covid-19 victim will be remembered as '],
#  'syndicator_name': ['NZ Herald'],
#  'paragraphs': [' There are six new cases of Covid-19 today and the Ministry of Health reports that another person has died of coronavirus.',
#   " George Hollings, a Rosewood Rest Home resident in his 80s, died in Christchurch's Burwood Hospital of the virus early this morning.",
#   ' "George had a lot of friends who the family don\'t have contact details for and they\'d like for them to have the opportunity to grieve along with his family," the Ministry of Health says.',
#   ' ',
#   '"His family tell us that George will be remembered as a real Kiwi bloke, a rough diamond, who loved his deer stalking," it said.',
#   ' Hollings\' family, in a statement to health officials, said: "We can\'t speak highly enough of the care Dad received. You\'ve clearly chosen the best, most compassionate staff to work at Burwood".',
#   ' "George was considered to be a probable case of COVID-19, and he also had underlying health conditions," the Ministry said.',
#   ' There are now 20 people who have died from Covid-19 in New Zealand.',
#   ' "Every person we lose to COVID-19 is a tragedy, with a family and friends left without their loved one. Our thoughts are with George\'s family today and in the coming days," the Ministry said.',
#   ' ',
#   " Five of today's cases can be traced to a known source, the Ministry says.",
#   ' Three of the cases were under Auckland District Health Board (DHB), two in Waitematā DHB and one in Canterbury.',
#   ' One case is still being investigated. The total of confirmed and probable cases is 1,485.',
#   " Of New Zealand's cases, 1,263 are reported as recovered – an increase of 11 on yesterday.",
#   ' Eighty five per cent of all confirmed and probable cases have now recovered.',
#   ' There are five people in hospital, and none in ICU.',
#   ' "Three clusters are now considered closed as there is no longer transmission of the virus associated with the cluster. A COVID-19 cluster is considered be closed after a total of 28 consecutive days – or two incubation periods for the virus – since its',
#   'most recent report date of a reported case," the Ministry said.',
#   ' A cluster linked to a Wellington wedding and two clusters linked to US travel (one in Wellington another in Auckland) closed today.',
#   ' ',
#   '• ']}

# %%
herald_data = pd.DataFrame(nzherald)

# %%
herald_data['date'] = pd.to_datetime(herald_data.date)

# %%
herald_data['paragraphs'] = herald_data.paragraphs.apply(lambda x: '\n'.join([s.strip() for s in x]).strip())

# %%
herald_data['byline'] = herald_data.byline.apply(lambda x: '\n'.join([s.strip() for s in x]).strip() if x else '')

# %%
herald_data['headline'] = (herald_data.headline
    .apply(lambda x: re.sub('\s{2,}', ' ', ' '.join([s.strip() for s in x]).strip()))
)

# %%
herald_data['subheader'] = herald_data.subheader.apply(lambda x: ' '.join(set(x))).str.replace("<[^>]+>", "")

# %%
herald_data['sponsor'] = herald_data.sponsor.apply(lambda x: ''.join(x))

# %%
herald_data['syndicator_name'] = herald_data.syndicator_name.apply(lambda x: ''.join(x))

# %%
herald_data.head()
# Out:
#                                                  url  \
# 0  https://www.nzherald.co.nz/nz/news/article.cfm...
# 1  https://www.nzherald.co.nz/business/news/artic...
# 2  https://www.nzherald.co.nz/business/news/artic...
# 3  https://www.nzherald.co.nz/business/news/artic...
# 4  https://www.nzherald.co.nz/business/news/artic...
#
#                                               byline                date  \
# 0                                                    2020-05-02 12:44:00
# 1                                 By: Keith Bradsher 2020-04-29 09:48:00
# 2                            By: The editorial board 2020-04-29 10:54:00
# 3  By: David Fisher   Senior writer, NZ Herald da... 2020-03-07 05:00:00
# 4                                    By: Tim Harford 2020-04-29 11:33:00
#
#                                             headline sponsor  \
# 0  Six more Covid-19 cases; Chch man dies of coro...
# 1  Covid 19 coronavirus: China's factories are ba...
# 2  Covid 19 coronavirus: Antivirus fight takes a ...
# 3  Inside a multi-million-dollar, eight-year divo...
# 4      Comment: Why we fail to prepare for disasters
#
#                                            subheader  syndicator_name  \
# 0  The latest Covid-19 victim will be remembered as         NZ Herald
# 1  New York Times: Manufacturing giant once again...   New York Times
# 2  Financial Times: Furlough schemes will not be ...  Financial Times
# 3  Sarah Sparks split from Greg Olliver eight yea...
# 4  Financial Times: What makes us do nothing in t...  Financial Times
#
#                                           paragraphs
# 0  There are six new cases of Covid-19 today and ...
# 1  An unemployed young college graduate has stopp...
# 2  The Black Death is often credited with transfo...
# 3  There always seemed to be plenty, even when he...
# 4  New Orleans's Times-Picayune noted the inadequ...

# %%
def contains_letters(text):
    for ch in text:
        if ch.isalpha():
            return True
    return False

def contains_no_numbers(text):
    for ch in text:
        if ch.isnumeric():
            return False
    return True

def clean_token(text):
    return re.sub('[^A-z\-]', '', text)

def get_māori_words(text):
    tokens = []
    for token in word_tokenize(text):
        cleaned = clean_token(token)
        if is_maori(token) and contains_letters(token) and \
           contains_no_numbers(token):
            tokens.append(token)
    return tokens

# %%
import cProfile

# %%
cProfile.run("[is_maori(text) for text in herald_data.paragraphs.sample(10000)]", sort = 'tottime')
# Out:
#          11844538 function calls (11662780 primitive calls) in 6.131 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 189395/7670    2.604    0.000    6.090    0.001 reo_toolkit.py:23(is_maori)
#      7669    1.371    0.000    1.371    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
# 4088347/4088343    0.278    0.000    0.278    0.000 {built-in method builtins.len}
#   3684765    0.272    0.000    0.272    0.000 {method 'append' of 'list' objects}
#    446376    0.269    0.000    0.269    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#    180088    0.253    0.000    0.388    0.000 encoders.py:31(encode)
#    372760    0.172    0.000    0.172    0.000 re.py:286(_compile)
#    163441    0.146    0.000    0.321    0.000 __init__.py:1904(debug)
#    720352    0.114    0.000    0.114    0.000 {method 'replace' of 'str' objects}
#    181726    0.104    0.000    0.346    0.000 utils.py:12(is_camel_case)
#    181726    0.079    0.000    0.228    0.000 re.py:214(findall)
#    181726    0.073    0.000    0.073    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
#    163441    0.072    0.000    0.107    0.000 __init__.py:1544(isEnabledFor)
#    163441    0.056    0.000    0.056    0.000 {method 'format' of 'str' objects}
#    163441    0.056    0.000    0.163    0.000 __init__.py:1286(debug)
#    189395    0.053    0.000    0.149    0.000 re.py:231(compile)
#    163441    0.035    0.000    0.035    0.000 __init__.py:1530(getEffectiveLevel)
#         1    0.029    0.029    6.119    6.119 <string>:1(<listcomp>)
#    181728    0.024    0.000    0.024    0.000 {method 'group' of '_sre.SRE_Match' objects}
#    180093    0.021    0.000    0.021    0.000 {method 'items' of 'dict' objects}
#    189395    0.021    0.000    0.021    0.000 {method 'strip' of 'str' objects}
#         1    0.008    0.008    0.008    0.008 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#     29416    0.006    0.000    0.006    0.000 {method 'capitalize' of 'str' objects}
#      3326    0.004    0.000    0.008    0.000 utils.py:16(camel_case_split)
#         2    0.003    0.001    0.003    0.001 {method 'take' of 'numpy.ndarray' objects}
#      9262    0.002    0.000    0.018    0.000 {built-in method builtins.all}
#      3326    0.002    0.000    0.016    0.000 reo_toolkit.py:52(<genexpr>)
#      1638    0.001    0.000    0.001    0.000 {method 'finditer' of '_sre.SRE_Pattern' objects}
#      1638    0.001    0.000    0.003    0.000 re.py:224(finditer)
#         1    0.001    0.001    0.001    0.001 {built-in method numpy.arange}
#      2129    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    6.131    6.131 <string>:1(<module>)
#      11/4    0.000    0.000    0.000    0.000 sre_parse.py:470(_parse)
#        11    0.000    0.000    0.000    0.000 sre_compile.py:250(_optimize_charset)
#      14/4    0.000    0.000    0.000    0.000 sre_compile.py:64(_compile)
#       129    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        78    0.000    0.000    0.000    0.000 sre_parse.py:232(__next)
#         1    0.000    0.000    6.131    6.131 {built-in method builtins.exec}
#         1    0.000    0.000    0.004    0.004 series.py:806(take)
#       9/4    0.000    0.000    0.000    0.000 sre_parse.py:407(_parse_sub)
#        55    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#      14/8    0.000    0.000    0.000    0.000 sre_parse.py:173(getwidth)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:844(parse)
#         4    0.000    0.000    0.001    0.000 sre_compile.py:557(compile)
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 sre_compile.py:482(_compile_info)
#         2    0.000    0.000    0.000    0.000 managers.py:1467(__init__)
#         8    0.000    0.000    0.000    0.000 enum.py:803(__and__)
#         2    0.000    0.000    0.000    0.000 series.py:183(__init__)
#        33    0.000    0.000    0.000    0.000 sre_parse.py:163(__getitem__)
#        11    0.000    0.000    0.000    0.000 sre_compile.py:223(_compile_charset)
#         1    0.000    0.000    0.000    0.000 base.py:276(__new__)
#         5    0.000    0.000    0.000    0.000 common.py:1708(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 blocks.py:2981(get_block_type)
#         1    0.000    0.000    0.012    0.012 generic.py:4866(sample)
#        35    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         2    0.000    0.000    0.001    0.000 range.py:155(_data)
#         1    0.000    0.000    0.000    0.000 base.py:1026(__iter__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1740(basicConfig)
#         1    0.000    0.000    0.000    0.000 managers.py:979(iget)
#         4    0.000    0.000    0.000    0.000 generic.py:5276(__setattr__)
#        37    0.000    0.000    0.000    0.000 generic.py:10(_check)
#        43    0.000    0.000    0.000    0.000 sre_parse.py:248(match)
#        53    0.000    0.000    0.000    0.000 sre_parse.py:253(get)
#        31    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 blocks.py:3027(make_block)
#         2    0.000    0.000    0.000    0.000 blocks.py:118(__init__)
#         2    0.000    0.000    0.000    0.000 generic.py:190(__init__)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:223(__init__)
#       3/2    0.000    0.000    0.000    0.000 generic.py:5257(__getattr__)
#         4    0.000    0.000    0.000    0.000 sre_compile.py:542(_code)
#         3    0.000    0.000    0.000    0.000 sre_parse.py:294(_class_escape)
#        16    0.000    0.000    0.000    0.000 enum.py:267(__call__)
#         2    0.000    0.000    0.000    0.000 base.py:472(_simple_new)
#        14    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#        16    0.000    0.000    0.000    0.000 enum.py:517(__new__)
#         4    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         2    0.000    0.000    0.000    0.000 blocks.py:251(mgr_locs)
#         1    0.000    0.000    0.001    0.001 base.py:744(take)
#         1    0.000    0.000    0.001    0.001 base.py:3638(values)
#         4    0.000    0.000    0.000    0.000 common.py:542(is_categorical_dtype)
#         2    0.000    0.000    0.000    0.000 blocks.py:2591(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:2767(__getitem__)
#         1    0.000    0.000    0.000    0.000 base.py:544(_shallow_copy_with_infer)
#         1    0.000    0.000    0.000    0.000 common.py:252(is_sparse)
#         4    0.000    0.000    0.000    0.000 common.py:1565(is_extension_array_dtype)
#        25    0.000    0.000    0.000    0.000 sre_parse.py:285(tell)
#         2    0.000    0.000    0.000    0.000 series.py:376(_set_axis)
#         2    0.000    0.000    0.000    0.000 managers.py:1548(dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:3581(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 generic.py:5235(__finalize__)
#         2    0.000    0.000    0.000    0.000 base.py:3897(__contains__)
#         9    0.000    0.000    0.000    0.000 base.py:247(is_dtype)
#         3    0.000    0.000    0.000    0.000 series.py:428(name)
#         3    0.000    0.000    0.000    0.000 series.py:432(name)
#         1    0.000    0.000    0.000    0.000 managers.py:950(get)
#         5    0.000    0.000    0.000    0.000 managers.py:1565(internal_values)
#         1    0.000    0.000    0.000    0.000 range.py:387(_shallow_copy)
#         1    0.000    0.000    0.000    0.000 numeric.py:53(__new__)
#         2    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         3    0.000    0.000    0.000    0.000 common.py:506(is_interval_dtype)
#         4    0.000    0.000    0.000    0.000 dtypes.py:75(find)
#         2    0.000    0.000    0.000    0.000 dtypes.py:1124(is_dtype)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#         1    0.000    0.000    0.000    0.000 __init__.py:771(__init__)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:828(fix_flags)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         8    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 series.py:403(_set_subtyp)
#         6    0.000    0.000    0.000    0.000 inference.py:358(is_hashable)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         2    0.000    0.000    0.000    0.000 dtypes.py:917(is_dtype)
#         8    0.000    0.000    0.000    0.000 sre_compile.py:539(isstring)
#        10    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:388(_simple)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         2    0.000    0.000    0.000    0.000 series.py:414(dtype)
#         5    0.000    0.000    0.000    0.000 series.py:480(_values)
#         1    0.000    0.000    0.000    0.000 range.py:170(_int64index)
#         1    0.000    0.000    0.000    0.000 common.py:399(random_state)
#         1    0.000    0.000    0.000    0.000 missing.py:132(_isna_new)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2843(prod)
#         1    0.000    0.000    0.000    0.000 __init__.py:960(__init__)
#         4    0.000    0.000    0.000    0.000 sre_compile.py:441(_get_charset_prefix)
#         9    0.000    0.000    0.000    0.000 sre_parse.py:159(__len__)
#        17    0.000    0.000    0.000    0.000 sre_parse.py:171(append)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 blocks.py:365(iget)
#         1    0.000    0.000    0.000    0.000 numeric.py:107(_shallow_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:396(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 generic.py:491(_info_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:3227(_set_as_cached)
#         1    0.000    0.000    0.000    0.000 frame.py:3073(_box_col_values)
#         3    0.000    0.000    0.000    0.000 base.py:1182(name)
#         1    0.000    0.000    0.000    0.000 base.py:1679(is_object)
#         2    0.000    0.000    0.000    0.000 base.py:2637(get_loc)
#         1    0.000    0.000    0.000    0.000 base.py:3911(__getitem__)
#         2    0.000    0.000    0.000    0.000 base.py:5393(maybe_extract_name)
#         4    0.000    0.000    0.000    0.000 common.py:208(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:339(is_categorical)
#         3    0.000    0.000    0.000    0.000 common.py:472(is_period_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:1672(_get_dtype)
#         3    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         3    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:471(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:752(_addHandlerRef)
#         1    0.000    0.000    0.000    0.000 __init__.py:800(createLock)
#         4    0.000    0.000    0.000    0.000 sre_compile.py:414(_get_literal_prefix)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 series.py:359(_constructor)
#         2    0.000    0.000    0.000    0.000 blocks.py:339(dtype)
#         1    0.000    0.000    0.000    0.000 range.py:210(start)
#         2    0.000    0.000    0.000    0.000 blocks.py:129(_check_ndim)
#         1    0.000    0.000    0.000    0.000 frame.py:3066(_box_item_values)
#         1    0.000    0.000    0.000    0.000 base.py:615(__len__)
#         1    0.000    0.000    0.000    0.000 base.py:3949(_can_hold_identifiers_and_holds_name)
#         1    0.000    0.000    0.000    0.000 base.py:619(shape)
#         1    0.000    0.000    0.000    0.000 common.py:222(is_object_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:372(is_datetime64_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:403(is_datetime64tz_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:441(is_timedelta64_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:685(is_dtype_equal)
#         2    0.000    0.000    0.000    0.000 common.py:987(is_datetime64_any_dtype)
#         1    0.000    0.000    0.000    0.000 missing.py:49(isna)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 sre_parse.py:167(__setitem__)
#         8    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9d12c0}
#         7    0.000    0.000    0.000    0.000 managers.py:1520(_block)
#         5    0.000    0.000    0.000    0.000 blocks.py:213(internal_values)
#         1    0.000    0.000    0.000    0.000 blocks.py:275(make_block_same_class)
#         2    0.000    0.000    0.000    0.000 numeric.py:155(is_all_dates)
#         1    0.000    0.000    0.000    0.000 base.py:509(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:505(_get_attributes_dict)
#         2    0.000    0.000    0.000    0.000 base.py:592(_reset_identity)
#         1    0.000    0.000    0.000    0.000 function.py:42(__call__)
#         1    0.000    0.000    0.000    0.000 common.py:151(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:330(apply_if_callable)
#         4    0.000    0.000    0.000    0.000 common.py:206(classes)
#         1    0.000    0.000    0.000    0.000 common.py:211(classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 common.py:830(is_signed_integer_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:1844(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2838(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 __init__.py:190(_checkLevel)
#         1    0.000    0.000    0.000    0.000 __init__.py:685(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:74(RLock)
#         1    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         2    0.000    0.000    0.000    0.000 managers.py:232(items)
#         1    0.000    0.000    0.000    0.000 range.py:233(stop)
#         1    0.000    0.000    0.000    0.000 range.py:256(step)
#         2    0.000    0.000    0.000    0.000 blocks.py:247(mgr_locs)
#         1    0.000    0.000    0.000    0.000 numeric.py:83(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:238(attrs)
#         1    0.000    0.000    0.000    0.000 base.py:1383(nlevels)
#         1    0.000    0.000    0.000    0.000 base.py:5293(ensure_index)
#         1    0.000    0.000    0.000    0.000 common.py:216(<lambda>)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:1456(addHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:384(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:870(setFormatter)
#         1    0.000    0.000    0.000    0.000 re.py:179(search)

# %%
# %%time
herald_data['māori_words'] = parallel_process(herald_data.paragraphs, get_māori_words, n_jobs = cpu_count()-1)
# Out:
# 100%|██████████| 448k/448k [02:26<00:00, 3.05kit/s]
# 448084it [00:00, 557972.21it/s]
# CPU times: user 1min 58s, sys: 17.4 s, total: 2min 16s
# Wall time: 3min 34s

# %%
# %%time
herald_data.to_csv("../data/herald_data.csv", index = False)
# Out:
# CPU times: user 29.8 s, sys: 837 ms, total: 30.6 s
# Wall time: 32 s

# %%
herald_data.head()
# Out:
#                                                  url  \
# 0  https://www.nzherald.co.nz/nz/news/article.cfm...
# 1  https://www.nzherald.co.nz/business/news/artic...
# 2  https://www.nzherald.co.nz/business/news/artic...
# 3  https://www.nzherald.co.nz/business/news/artic...
# 4  https://www.nzherald.co.nz/business/news/artic...
#
#                                               byline                date  \
# 0                                                    2020-05-02 12:44:00
# 1                                 By: Keith Bradsher 2020-04-29 09:48:00
# 2                            By: The editorial board 2020-04-29 10:54:00
# 3  By: David Fisher   Senior writer, NZ Herald da... 2020-03-07 05:00:00
# 4                                    By: Tim Harford 2020-04-29 11:33:00
#
#                                             headline sponsor  \
# 0  Six more Covid-19 cases; Chch man dies of coro...
# 1  Covid 19 coronavirus: China's factories are ba...
# 2  Covid 19 coronavirus: Antivirus fight takes a ...
# 3  Inside a multi-million-dollar, eight-year divo...
# 4      Comment: Why we fail to prepare for disasters
#
#                                            subheader  syndicator_name  \
# 0  The latest Covid-19 victim will be remembered as         NZ Herald
# 1  New York Times: Manufacturing giant once again...   New York Times
# 2  Financial Times: Furlough schemes will not be ...  Financial Times
# 3  Sarah Sparks split from Greg Olliver eight yea...
# 4  Financial Times: What makes us do nothing in t...  Financial Times
#
#                                           paragraphs  \
# 0  There are six new cases of Covid-19 today and ...
# 1  An unemployed young college graduate has stopp...
# 2  The Black Death is often credited with transfo...
# 3  There always seemed to be plenty, even when he...
# 4  New Orleans's Times-Picayune noted the inadequ...
#
#                                          māori_words
# 0  [a, a, to, to, a, Kiwi, a, a, to, to, to, a, h...
# 1  [A, a, no, to, a, a, to, to, a, a, to, to, a, ...
# 2  [to, a, to, to, to, to, to, a, to, a, a, to, a...
# 3  [to, he, to, a, a, I, I, to, a, he, to, to, He...
# 4  [a, a, a, a, A, a, to, a, to, to, He, to, no, ...

# %%
class NoMacronEncoder():

    encoder_dict = {
        'ā': 'a',
        'ē': 'e',
        'ī': 'i',
        'ō': 'o',
        'ū': 'u'
    }

    decoder_dict = {v: k for k, v in encoder_dict.items()}

    def encode(self, text):
        for k, v in self.encoder_dict.items():
            text = text.replace(k, v)
        return text

    def decode(self, text):
        return text

# %%
words_by_date = (herald_data.sort_values('date', ascending = False)
     .loc[
    herald_data.māori_words.apply(len) > 0, 
    ['date', 'māori_words']
    ].explode('māori_words')
    .reset_index(drop = True)
)

# %%
words_by_date['no_macrons'] = words_by_date.māori_words.apply(lambda s: NoMacronEncoder().encode(s))

# %%
words_by_date['has_macrons'] = words_by_date.māori_words.apply(lambda s: NoMacronEncoder().encode(s) != s)

# %%
words_by_date[words_by_date.has_macrons]
# Out:
#                         date    māori_words     no_macrons  has_macrons
# 420      2020-05-02 19:04:00          Taupō          Taupo         True
# 1268     2020-05-02 13:42:00         whānau         whanau         True
# 1399     2020-05-02 12:52:00          Māori          Maori         True
# 1408     2020-05-02 12:52:00          Māori          Maori         True
# 1417     2020-05-02 12:52:00          Māori          Maori         True
# ...                      ...            ...            ...          ...
# 9758350  2011-07-06 10:21:00            anā            ana         True
# 9758352  2011-07-06 10:21:00            Anā            Ana         True
# 9758358  2011-07-06 10:21:00          Māori          Maori         True
# 10150816 2011-03-05 14:49:00  Taupō-Rotorua  Taupo-Rotorua         True
# 11959011 2008-03-26 08:00:00         Kāpiti         Kapiti         True
#
# [29990 rows x 4 columns]

# %%
len(set(w for l in herald_data.māori_words for w in l)) * len(herald_data)
# Out:
# 10577918988

# %%
pd.Series([w for l in herald_data.māori_words.values for w in l]).value_counts().head(500)
